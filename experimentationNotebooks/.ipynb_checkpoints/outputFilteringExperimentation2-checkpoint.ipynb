# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal as sig
# %matplotlib inline

# %%
dfConst = pd.read_csv('/home/raricktj/Documents/neuroprocessorProject/neuro-simulation/collected_output/simple_synapse/constant/0002/output.csv',
                 names=['time', 'v1', 'v2'])
dfAdapt = pd.read_csv('/home/raricktj/Documents/neuroprocessorProject/neuro-simulation/collected_output/simple_synapse/adaptive/0002/output.csv',
                 names=['time', 'v1', 'v2'])
dfConst.head()
dt = dfConst['time'][1] - dfConst['time'][0]

# %%
df = dfConst['v1'].rolling(int(1/dt)).max()
df.plot()

# %%
# Filter out non-peaks
df[(df < -0.02)] = 0
df[(df != 0)] = 1
df.plot()

# %%
df.diff().plot()

# %%
df.diff().value_counts()
# Out:
#  0.0    499885
# -1.0         7
#  1.0         7
# Name: v1, dtype: int64
